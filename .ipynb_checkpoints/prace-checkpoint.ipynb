# %%
# %matplotlib inline
import numpy as np 
import matplotlib as mp
numbers=np.random.normal(25000,1000,2000)
import matplotlib.pyplot as plot
plot.hist(numbers,20)
plot.show()

# %%
np.median(numbers)
# Out:
# 24963.338424016474

# %%
numbers.std()
numbers.var()
# Out:
# 1041408.3692873478

# %%
from scipy import stats
ages=np.random.randint(10,high=78,size=500)
stats.mode(ages)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7276\607759427.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(ages)
# ModeResult(mode=array([45]), count=array([13]))

# %%
#16
import numpy as np 
import matplotlib.pyplot as plot 
values=np.random.uniform(10,20,1000)
plot.hist(values,10)
plot.show()

# %%
#17
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import norm
values=np.arange(-5,5,0.001)
plt.plot(values,norm.pdf(values))

# %%
#17 expon 
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import expon
numbers=np.arange(5,10,0.01)
plt.plot(numbers,expon.pdf(numbers))

# %%
#18 pmf binom
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import binom
numbers=np.arange(5,10,0.001)
plt.plot(numbers,binom.pmf(numbers,4,0.5))

# %%
#19 percentile:صدک
import numpy as np
import matplotlib.pyplot as plot
values=np.random.normal(5,0.5,1000)
plot.hist(values,50)
plot.show()
np.percentile(values,30)
# Out:
# 4.729832231734223

# %%
#20 کشیدگی و چولگی
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
values=np.random.normal(10,0.1,1000)
plt.hist(values,30)
plt.show()
np.mean(values)
# Out:
# 9.997443805491603

# %%
np.var(values) #واریانس
# Out:
# 0.00982984749320065

# %%
np.std(values) #انحراف معیار
# Out:
# 0.09914558736121669

# %%
st.kurtosis(values) #کشیدگی
# Out:
# -0.0063040754498242535

# %%
st.skew(values) #چولگی
# Out:
# 0.0504210389901504
